# %% [markdown]
# # **Tugas1_Kelompok29**
#
# Kelompok 29 :
# 1. Muhammad Syamsul Saputra (Better)
# 2. Putri Tanaza Aji Pratiwi (Atlas)
# 3. Daulat Rais (Perseverse)
# 4. Yunita Nurisfa Maya Sakti (Visioner)
# 5. Femmy Reihan Ananda Jaya (Alan Turning)

# %% [markdown]
# ## **Soal**
#
# 1. Cari dan tulikan contoh aplikasi/implementasi RL di bidang anda!
# 2. Jelaskan secara singkat mengapa aplikasi tersebut merupakan aplikasi berbasis RL, jelaskan berdasarkan kesesuaian dengan karakteristik RL!
# 3. Dari aplikasi tersebut, tentukan: (a) Objective (b) State (c) Action (d) Reward (e) Termination.
# 4. Berdasarkan 3 nomor di atas, utarakan/jelaskan pemahaman anda tentang RL, terkait karakteristik, derajat kemudahan/kesulitan untuk diaplikasikan menyelesaikan masalah riil dst.

# %% [markdown]
# ## Jawaban

# %% [markdown]
# 1. Game ‘Shadow of the Colossus’
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Karena Agent akan belajar mendapatkan reward, berdasarkan Action yang dilakukan pada suatu kondisi.

# %% [markdown]
# 3. <ol type=a>
#   <li>Objective : Mengalahkan 16 Monster/Colossi</li>
#   <li>State : Padang rumput, Pegunungan, Gua raksasa</li>
#   <li>Action: Menyerang</li>
#   <li>Reward: Item</li>
#   <li>Termination: Terbunuh</li>
# </ol>

# %% [markdown]
# 4. <ul>
#   <li>Tujuan utama reinforcement machine learning bagi agen adalah untuk menentukan aksi apa yang memaksimalkan hasil dalam waktu yang ditentukan.</li>
#   <li>Karakteristik : Pengambilan keputusan berurutan, tidak ada supervisor, hanya ada bilangan real atau reward Pemilihan waktu dalam reinforcement sangatlah penting Action dari sebuah agent akan menentukan data selanjutnya yang diterimanya dan untuk melakukan aksi selanjutnya.</li>
#   <li>Derajat kemudahan ditemukan pada algoritma yang mempelajari hal baru dan akan berdampak kedepannya.</li>
#   <li>Derajat kesulitan membaca apa yang akan dikeluarkan lawan karena struktur dan kemungkinan yang dilakukan memiliki banyak peluang.</li>
# </ul>
