# %% [markdown]
# Contoh yang diambil dari openAi adalah Frozen Lake Problem menggunakan Monte Carlo Algorithm:
#
# -Program berjalan berdasarkan episode sebelumnya
#
# -Contoh : Pemain berjalan ke blok 1, ia mencari action yang mempunyai reward paling baik, lalu melanjutkan berjalan ke blok yang memiliki reward paling baik tersebut
#
# ![image.png](data:image/png;base64,...)
